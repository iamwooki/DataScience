# %% [markdown]
# # **Import package**

# %%
'''
pandas basic : https://doorbw.tistory.com/172
matplot : https://doorbw.tistory.com/173

'''
import pandas as pd 
import matplotlib.pyplot as plt #자료구조 시각화
import seaborn as sns
sns.set(color_codes=True) #plot에서 색 적용
from pandas.plotting import scatter_matrix
# notebook을 실행한 브라우저에서 바로 그림을 볼 수 있게 해주는 것
# %matplotlib inline

# %% [markdown]
# #**Load data**

# %%
'''
only once
'''
#Iris dataset 가져오기
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = pd.read_csv(url, names=names)
#dataset csv저장
dataset.to_csv('iris.csv',index=False)

#일부만 출력해보기
dataset.head()
dataset.tail(6)
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           class
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# #**Summary**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal-length    150 non-null float64
# sepal-width     150 non-null float64
# petal-length    150 non-null float64
# petal-width     150 non-null float64
# class           150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
dataset.describe() #데이터 수치 통계 정리
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dataset.groupby('class').size() #데이터를 클래스 그룹별로 정리
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# #**Visualization**

# %%
dataset.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
# Out:
# sepal-length       AxesSubplot(0.125,0.536818;0.352273x0.343182)
# sepal-width     AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# petal-length          AxesSubplot(0.125,0.125;0.352273x0.343182)
# petal-width        AxesSubplot(0.547727,0.125;0.352273x0.343182)
# dtype: object

# %%
dataset.plot(kind='box', sharex=False, sharey=False)

# %%
dataset.boxplot(by='class', grid=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f183e7dae10>,
# ...
#       dtype=object)

# %%
sns.violinplot(data=dataset, x='class', y='sepal-length') #바이올린 플랏

# %%
dataset.hist(edgecolor='black', linewidth=1.2, grid=False ) #히스토그램
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f183e415780>,
# ...
#       dtype=object)

# %%
scatter_matrix(dataset)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f183e4e31d0>,
# ...
#       dtype=object)

# %%
sns.pairplot(dataset, hue='class')

# %%
sns.pairplot(dataset, hue='class', diag_kind='kde')
